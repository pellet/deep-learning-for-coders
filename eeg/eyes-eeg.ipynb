# %%
# %pip install openneuro-py mne mne-bids -Uqq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import os.path as op
import openneuro

from mne.datasets import sample
from mne_bids import BIDSPath, read_raw_bids, print_dir_tree, make_report

# %%
dataset = 'ds003685'
bids_root = op.join(op.dirname(sample.data_path()), dataset)
if not op.isdir(bids_root):
    os.makedirs(bids_root)

print(make_report(bids_root))

openneuro.download(dataset=dataset, target_dir=bids_root,
                   include=['sub-01*eyes*'])
# Out:
# Summarizing participants.tsv /Users/pellet/mne_data/ds003685/participants.tsv...
# The participant template found: comprised of 28 male and 32 female participants;
# handedness were all unknown;
# ages ranged from 18.0 to 28.0 (mean = 20.0, std = 1.89; 5 with unknown age)
#  The A test-retest resting and cognitive state EEG dataset dataset was created
# by Yulin Wang, Wei Duan, Lihong Ding, Debo Dong, and Xu Lei and conforms to BIDS
# version 1.2. This report was generated with MNE-BIDS
# (https://doi.org/10.21105/joss.01896). The dataset consists of 9 participants
# (comprised of 28 male and 32 female participants; handedness were all unknown;
# ages ranged from 18.0 to 28.0 (mean = 20.0, std = 1.89; 5 with unknown age)) and
# 3 recording sessions: session1, session2, and session3.
#
# 👋 Hello! This is openneuro-py 2022.1.0. Great to see you! 🤗
#
#    👉 Please report problems 🤯 and bugs 🪲 at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# 🌍 Preparing to download ds003685 …
# /var/folders/23/fzc0x7wn53q2m_2n53dlm5xr0000gn/T/ipykernel_39834/2421265521.py:6: RuntimeWarning: No *scans.tsv files found. Currently, we do not generate a report without the scans.tsv files.
#   print(make_report(bids_root))
# 👉 Retrieving up to 40 files (5 concurrent downloads).
# ✅ Finished downloading ds003685.
#
# 🧠 Please enjoy your brains.
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<_download_files() done, defined at /opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/openneuro/download.py:439> exception=ImportError('IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html')>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/openneuro/download.py", line 468, in _download_files
#     await asyncio.gather(*download_tasks)
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/openneuro/download.py", line 334, in _download_file
#     await _retrieve_and_write_to_disk(
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/openneuro/download.py", line 408, in _retrieve_and_write_to_disk
#     with tqdm(desc=desc, initial=local_file_size,
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/tqdm/notebook.py", line 239, in __init__
#     self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/tqdm/notebook.py", line 112, in status_printer
#     raise ImportError(
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
print_dir_tree(bids_root, max_depth=4)
# Out:
# |ds003685/
# |--- CHANGES
# |--- README
# |--- dataset_description.json
# |--- participants.tsv
# |--- sub-01/
# |------ ses-session1/
# |--------- .DS_Store
# |--------- eeg/
# |------------ sub-01_ses-session1_task-eyes closed_run-1_channels.tsv
# |------------ sub-01_ses-session1_task-eyes closed_run-1_eeg.eeg
# |------------ sub-01_ses-session1_task-eyes closed_run-1_eeg.json
# |------------ sub-01_ses-session1_task-eyes closed_run-1_eeg.vhdr
# |------------ sub-01_ses-session1_task-eyes closed_run-1_eeg.vmrk
# |------------ sub-01_ses-session1_task-eyes closed_run-1_events.tsv
# |------------ sub-01_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-01_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-01_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-01_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-01_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-01_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-01_ses-session2_task-eyes closed_run-1_channels.tsv
# |------------ sub-01_ses-session2_task-eyes closed_run-1_eeg.eeg
# |------------ sub-01_ses-session2_task-eyes closed_run-1_eeg.json
# |------------ sub-01_ses-session2_task-eyes closed_run-1_eeg.vhdr
# |------------ sub-01_ses-session2_task-eyes closed_run-1_eeg.vmrk
# |------------ sub-01_ses-session2_task-eyes closed_run-1_events.tsv
# |------------ sub-01_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-01_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-01_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-01_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-01_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-01_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-01_ses-session3_task-eyes closed_run-1_channels.tsv
# |------------ sub-01_ses-session3_task-eyes closed_run-1_eeg.eeg
# |------------ sub-01_ses-session3_task-eyes closed_run-1_eeg.json
# |------------ sub-01_ses-session3_task-eyes closed_run-1_eeg.vhdr
# |------------ sub-01_ses-session3_task-eyes closed_run-1_eeg.vmrk
# |------------ sub-01_ses-session3_task-eyes closed_run-1_events.tsv
# |------------ sub-01_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-01_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-01_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-01_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-01_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-01_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-02/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-02_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-02_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-02_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-02_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-02_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-02_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-02_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-02_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-02_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-02_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-02_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-02_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-02_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-02_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-02_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-02_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-02_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-02_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-03/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-03_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-03_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-03_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-03_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-03_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-03_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-03_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-03_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-03_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-03_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-03_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-03_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-03_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-03_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-03_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-03_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-03_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-03_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-04/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-04_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-04_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-04_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-04_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-04_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-04_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-04_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-04_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-04_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-04_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-04_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-04_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-04_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-04_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-04_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-04_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-04_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-04_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-05/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-05_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-05_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-05_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-05_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-05_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-05_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-05_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-05_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-05_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-05_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-05_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-05_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-05_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-05_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-05_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-05_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-05_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-05_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-06/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-06_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-06_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-06_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-06_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-06_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-06_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-06_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-06_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-06_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-06_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-06_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-06_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-06_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-06_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-06_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-06_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-06_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-06_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-07/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-07_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-07_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-07_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-07_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-07_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-07_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-07_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-07_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-07_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-07_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-07_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-07_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-07_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-07_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-07_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-07_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-07_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-07_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-08/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-08_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-08_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-08_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-08_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-08_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-08_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-08_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-08_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-08_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-08_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-08_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-08_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-08_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-08_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-08_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-08_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-08_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-08_ses-session3_task-eyes open_run-2_events.tsv
# |--- sub-09/
# |------ ses-session1/
# |--------- eeg/
# |------------ sub-09_ses-session1_task-eyes open_run-2_channels.tsv
# |------------ sub-09_ses-session1_task-eyes open_run-2_eeg.eeg
# |------------ sub-09_ses-session1_task-eyes open_run-2_eeg.json
# |------------ sub-09_ses-session1_task-eyes open_run-2_eeg.vhdr
# |------------ sub-09_ses-session1_task-eyes open_run-2_eeg.vmrk
# |------------ sub-09_ses-session1_task-eyes open_run-2_events.tsv
# |------ ses-session2/
# |--------- eeg/
# |------------ sub-09_ses-session2_task-eyes open_run-2_channels.tsv
# |------------ sub-09_ses-session2_task-eyes open_run-2_eeg.eeg
# |------------ sub-09_ses-session2_task-eyes open_run-2_eeg.json
# |------------ sub-09_ses-session2_task-eyes open_run-2_eeg.vhdr
# |------------ sub-09_ses-session2_task-eyes open_run-2_eeg.vmrk
# |------------ sub-09_ses-session2_task-eyes open_run-2_events.tsv
# |------ ses-session3/
# |--------- eeg/
# |------------ sub-09_ses-session3_task-eyes open_run-2_channels.tsv
# |------------ sub-09_ses-session3_task-eyes open_run-2_eeg.eeg
# |------------ sub-09_ses-session3_task-eyes open_run-2_eeg.json
# |------------ sub-09_ses-session3_task-eyes open_run-2_eeg.vhdr
# |------------ sub-09_ses-session3_task-eyes open_run-2_eeg.vmrk
# |------------ sub-09_ses-session3_task-eyes open_run-2_events.tsv

# %%
print(make_report(bids_root))
# Out:
# Summarizing participants.tsv /Users/pellet/mne_data/ds003685/participants.tsv...
# The participant template found: comprised of 28 male and 32 female participants;
# handedness were all unknown;
# ages ranged from 18.0 to 28.0 (mean = 20.0, std = 1.89; 5 with unknown age)
#  The A test-retest resting and cognitive state EEG dataset dataset was created
# by Yulin Wang, Wei Duan, Lihong Ding, Debo Dong, and Xu Lei and conforms to BIDS
# version 1.2. This report was generated with MNE-BIDS
# (https://doi.org/10.21105/joss.01896). The dataset consists of 9 participants
# (comprised of 28 male and 32 female participants; handedness were all unknown;
# ages ranged from 18.0 to 28.0 (mean = 20.0, std = 1.89; 5 with unknown age)) and
# 3 recording sessions: session1, session2, and session3.
# /var/folders/23/fzc0x7wn53q2m_2n53dlm5xr0000gn/T/ipykernel_39834/3390368180.py:1: RuntimeWarning: No *scans.tsv files found. Currently, we do not generate a report without the scans.tsv files.
#   print(make_report(bids_root))

# %%
#fix files missing spaces

import re, glob, os

def renamer(files, pattern, replacement):
    for pathname in glob.glob(files, recursive=True):
        new_filename = re.sub(pattern, replacement, pathname)
        if new_filename != pathname:
            os.rename(
              pathname,
              os.path.join(os.path.dirname(pathname), new_filename))
            print('renamed to {}'.format(os.path.join(os.path.dirname(pathname), new_filename)))

renamer('{}/**/*'.format(bids_root), 'eyesopen', 'eyes open')
renamer('{}/**/*'.format(bids_root), 'eyesclosed', 'eyes closed')
